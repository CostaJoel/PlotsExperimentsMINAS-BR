# %% [markdown]
# # Setup

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from scripts import plots

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
result_path = "../results_to_plot/"

# %% [markdown]
# # MOA1

# %%
moa1_batch_cc = os.path.join(result_path, "MOA1/CC/CC-MeasuresOverTime.csv")
moa1_upper_eabr = os.path.join(result_path, "MOA1/EaBR/EaBR-MeasuresOverTime.csv")
moa1_bracis = os.path.join(result_path, "MOA1/bracis_moa1_final/MeasuresOverTime.csv")
moa1_minasbr = os.path.join(result_path,"MOA1/minas-br_MOA1/MeasuresOverTime.csv")

df_moa1_final = plots.concat_datasets_for_ploting(moa1_batch_cc,
                                            moa1_upper_eabr,
                                            moa1_bracis,
                                            moa1_minasbr)

df_moa1_final.Classifier.value_counts()
# Out:
# c:\Users\joeld\PlotsExperimentsMINAS-BR\data_analysis\scripts\plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# c:\Users\joeld\PlotsExperimentsMINAS-BR\data_analysis\scripts\plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"
# Classifier
# EaBR           50
# CC             50
# UnkRM_v2       49
# MINAS-BR_v2    49
# UnkRM_v1       49
# MINAS-BR_v1    49
# ...

# %%
np_info, concept_evolution_info  = plots.get_concept_evolution_np_info(
    os.path.join(result_path,"MOA1/minas-br_MOA1/")
)
print(concept_evolution_info)
np_info
# Out:
#     Timestamp    NP   AssociatedClass   TimestampAssociation  \
# 0       41877   NP1               5.0                43200.0
# 1       41877   NP2               NaN                    NaN
# 2       41877   NP3               5.0                43200.0
# 3       41877   NP4               5.0                43200.0
# 4       41877   NP5               5.0                43200.0
# 5       41877   NP6               NaN                    NaN
# 6       41877   NP7               NaN                    NaN
# 7       41877   NP8               5.0                43200.0
# 8       41877   NP9               5.0                43200.0
# 9       41877  NP10               5.0                54000.0
# 10      41877  NP11               5.0                43200.0
# 11      41877  NP12               NaN                    NaN
# 12      41877  NP13               NaN                    NaN
# 13      41877  NP14               5.0                43200.0
# ...

# %%
np_info_v1, concept_evolution_info  = plots.get_concept_evolution_np_info(
        os.path.join("../results_to_plot/MOA1/bracis_moa1_final/")
    )
print(concept_evolution_info)
np_info_v1
# Out:
#     Timestamp    NP   AssociatedClass   TimestampAssociation  \
# 0       51982   NP1               5.0                52200.0
# 1       51982   NP2               5.0                52200.0
# 2       51982   NP3               5.0                52200.0
# 3       51982   NP4               5.0                52200.0
# 4       51982   NP5               5.0                57600.0
# 5       51982   NP6               5.0                52200.0
# 6       51982   NP7               NaN                    NaN
# 7       51982   NP8               NaN                    NaN
# 8       51982   NP9               5.0                52200.0
# 9       51982  NP10               5.0                52200.0
# 10      51982  NP11               NaN                    NaN
# 11      51982  NP12               5.0                66600.0
# 12      51982  NP13               NaN                    NaN
# 13      51982  NP14               NaN                    NaN
# ...

# %%
from scripts import plots

plots.plot_measures_over_time_sinais(data=df_moa1_final,
                        np_info=np_info,
                        np_info_v1=np_info_v1,
                        concept_evolution_info=concept_evolution_info,
                        linewidth = 5,
                        markersize= 5,
                        savefig=True,
                        name_fig="moa1_F1M_teste.pdf")

# %% [markdown]
# # MOA2

# %%
moa2_batch = os.path.join(result_path, "MOA2/HOMER/HOMER-MeasuresOverTime.csv")
moa2_upper = os.path.join(result_path, "MOA2/EaBR/EaBR-MeasuresOverTime.csv")
moa2_bracis = os.path.join(result_path, "MOA2/bracis_moa2_final/MeasuresOverTime.csv")
moa2_minasbr = os.path.join(result_path,"MOA2/minas-br_MOA2/MeasuresOverTime.csv")

df_moa2_final = plots.concat_datasets_for_ploting(moa2_batch,
                                            moa2_upper,
                                            moa2_bracis,
                                            moa2_minasbr)

df_moa2_final.Classifier.value_counts()
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"
# MINAS-BR_v2    50
# EaBR           50
# UnkRM_v2       50
# HOMER          50
# MINAS-BR_v1    50
# UnkRM_v1       50
# Name: Classifier, dtype: int64

# %%
np_info, concept_evolution_info  = plots.get_concept_evolution_np_info(os.path.join(result_path,"MOA2/minas-br_MOA2/"))
print(concept_evolution_info)
np_info
# Out:
#      Timestamp     NP   AssociatedClass   TimestampAssociation  \
# 0         4973    NP1               NaN                    NaN
# 1         4973    NP2               NaN                    NaN
# 2         4973    NP3               NaN                    NaN
# 3         4973    NP4               NaN                    NaN
# 4         4973    NP5               0.0                13090.0
# ..         ...    ...               ...                    ...
# 126     120357  NP127               0.0               120428.0
# 127     120357  NP128               1.0               120428.0
# 128     120357  NP129               NaN                    NaN
# 129     120357  NP130               NaN                    NaN
# 130     120357  NP131               NaN                    NaN
#
#       windowAssociation
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    4.0
# ..                   ...
# 126                 45.0
# ...

# %%
np_info_v1, concept_evolution_info  = plots.get_concept_evolution_np_info(os.path.join(result_path,"MOA2/bracis_moa2_final/"))
print(concept_evolution_info)
np_info_v1
# Out:
#     Timestamp    NP   AssociatedClass   TimestampAssociation  \
# 0       13093   NP1               NaN                    NaN
# 1       13093   NP2               NaN                    NaN
# 2       13093   NP3               NaN                    NaN
# 3       13093   NP4               NaN                    NaN
# 4       13093   NP5               NaN                    NaN
# 5       13093   NP6               NaN                    NaN
# 6       13093   NP7               NaN                    NaN
# 7       13093   NP8               0.0                28798.0
# 8       13093   NP9               NaN                    NaN
# 9       13093  NP10               NaN                    NaN
# 10      13093  NP11               NaN                    NaN
# 11      13093  NP12               0.0                15708.0
# 12      13093  NP13               0.0                15708.0
# 13      13093  NP14               0.0                15708.0
# ...

# %%
plots.plot_measures_over_time_sinais(data=df_moa2_final,
                        np_info=np_info,
                        np_info_v1=np_info_v1,
                        concept_evolution_info=concept_evolution_info,
                        linewidth = 5,
                        markersize= 5,
                        savefig=True,
                        name_fig="moa2_F1M.pdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 plots.plot_measures_over_time_sinais(data=df_moa2_final,
#       2                         np_info=np_info,
#       3                         np_info_v1=np_info_v1,
#       4                         concept_evolution_info=concept_evolution_info,
#       5                         linewidth = 5,
#       6                         markersize= 5,
#       7                         savefig=True,
#       8                         name_fig="moa2_F1M.pdf")
#
# NameError: name 'df_moa2_final' is not defined

# %% [markdown]
# # Yeast Original

# %%
yeast_original_batch = os.path.join(result_path, "yeast_original/RandomSubspaceML/RandomSubspaceML-Results.csv")
yeast_original_upper = os.path.join(result_path, "yeast_original/EaCC/EaCC-Results.csv")
yeast_original_bracis = os.path.join(result_path, "yeast_original/bracis_yeast_original/MeasuresOverTime.csv")
yeast_original_minasbr = os.path.join(result_path,"yeast_original/minas-br_yeast_original/MeasuresOverTime.csv")

df_yeast_final = plots.concat_datasets_for_ploting(yeast_original_batch,
                                            yeast_original_upper,
                                            yeast_original_bracis,
                                            yeast_original_minasbr)

df_yeast_final.Classifier.value_counts()
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"
# MINAS-BR_v2         50
# EaCC                50
# UnkRM_v2            50
# MINAS-BR_v1         50
# UnkRM_v1            50
# RandomSubspaceML    50
# Name: Classifier, dtype: int64

# %%
np_info, concept_evolution_info  = plots.get_concept_evolution_np_info(os.path.join(result_path,"yeast_original/minas-br_yeast_original/"))
np_info_v1, concept_evolution_info  = plots.get_concept_evolution_np_info(os.path.join(result_path,"yeast_original/bracis_yeast_original/"))

print(concept_evolution_info)
print(np_info)
np_info_v1
# Out:
# Empty DataFrame
# Columns: [Timestamp,  NP,  AssociatedClass,  TimestampAssociation,  windowAssociation ]
# Index: []
# Empty DataFrame
# Columns: [Timestamp,  NP,  AssociatedClass,  TimestampAssociation,  windowAssociation ]
# Index: []
#    Timestamp  window  label
# 0        156       3     13
# None

# %%
plots.plot_measures_over_time_sinais(data=df_yeast_final,
                        np_info=np_info,
                        np_info_v1=np_info_v1,
                        concept_evolution_info=concept_evolution_info,
                        linewidth = 5,
                        markersize= 5,
                        savefig=True,
                        name_fig="yeast_original.pdf")

# %% [markdown]
# # Yeast modified

# %%
df_batch = os.path.join(result_path, "yeast_modified/CLR/CLR-MeasuresOverTime.csv")
df_upper = os.path.join(result_path, "yeast_modified/EaBR/EaBR-MeasuresOverTime.csv")
df_bracis = os.path.join(result_path, "yeast_modified/bracis_yeast_modified/MeasuresOverTime.csv")
df_minasbr = os.path.join(result_path,"yeast_modified/minas-br_yeast_modified/MeasuresOverTime.csv")

df_final = plots.concat_datasets_for_ploting(df_batch,
                                            df_upper,
                                            df_bracis,
                                            df_minasbr)

print(df_final.Classifier.value_counts())

np_info, concept_evolution_info  = plots.get_concept_evolution_np_info(os.path.join(result_path,"yeast_modified/minas-br_yeast_modified/"))
np_info_v1, concept_evolution_info  = plots.get_concept_evolution_np_info(os.path.join(result_path,"yeast_modified/bracis_yeast_modified/"))

plots.plot_measures_over_time_sinais(data=df_final,
                        np_info=np_info,
                        np_info_v1=np_info_v1,
                        concept_evolution_info=concept_evolution_info,
                        linewidth = 5,
                        markersize= 5,
                        savefig=True,
                        name_fig="yeast_modified.pdf")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"
# MINAS-BR_v2    50
# EaBR           50
# UnkRM_v2       50
# CLR            50
# MINAS-BR_v1    50
# UnkRM_v1       50
# Name: Classifier, dtype: int64
# Empty DataFrame
# ...

# %% [markdown]
# # Scene Original

# %%
df_batch = os.path.join(result_path, "scene_original/BPMLL/BPMLL-Results.csv")
df_upper = os.path.join(result_path, "scene_original/EaISOUPTree/EaISOUPTree-Results.csv")
df_bracis = os.path.join(result_path, "scene_original/bracis_scene_original/MeasuresOverTime.csv")
df_minasbr = os.path.join(result_path,"scene_original/minas-br_scene_original/MeasuresOverTime.csv")

df_final = plots.concat_datasets_for_ploting(df_batch,
                                            df_upper,
                                            df_bracis,
                                            df_minasbr)


np_info, concept_evolution_info  = plots.get_concept_evolution_np_info(os.path.join(result_path,"scene_original/minas-br_scene_original/"))
np_info_v1, concept_evolution_info  = plots.get_concept_evolution_np_info(os.path.join(result_path,"scene_original/bracis_scene_original/"))

plots.plot_measures_over_time_sinais(data=df_final,
                        np_info=np_info,
                        np_info_v1=np_info_v1,
                        concept_evolution_info=concept_evolution_info,
                        linewidth = 5,
                        markersize= 5,
                        savefig=True,
                        name_fig="scene_original.pdf")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"
# Empty DataFrame
# Columns: [Timestamp,  NP,  AssociatedClass,  TimestampAssociation,  windowAssociation ]
# Index: []
#    Timestamp   NP   AssociatedClass   TimestampAssociation  \
# ...

# %% [markdown]
# # Scene Modified

# %%
df_batch = os.path.join(result_path, "scene_modified/BPMLL/BPMLL-Results.csv")
df_upper = os.path.join(result_path, "scene_modified/EaISOUPTree/EaISOUPTree-MeasuresOverTime.csv")
df_bracis = os.path.join(result_path, "scene_modified/bracis_scene_modified/MeasuresOverTime.csv")
df_minasbr = os.path.join(result_path,"scene_modified/minas-br_scene_modified/MeasuresOverTime.csv")

df_final = plots.concat_datasets_for_ploting(df_batch,
                                            df_upper,
                                            df_bracis,
                                            df_minasbr)

np_info, concept_evolution_info  = plots.get_concept_evolution_np_info(os.path.join(result_path,"scene_modified/minas-br_scene_modified/"))
np_info_v1, concept_evolution_info  = plots.get_concept_evolution_np_info(os.path.join(result_path,"scene_modified/bracis_scene_modified/"))

plots.plot_measures_over_time_sinais(data=df_final,
                        np_info=np_info,
                        np_info_v1=np_info_v1,
                        concept_evolution_info=concept_evolution_info,
                        linewidth = 5,
                        markersize= 5,
                        savefig=True,
                        name_fig="scene_modified.pdf")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"
# Empty DataFrame
# Columns: [Timestamp,  NP,  AssociatedClass,  TimestampAssociation,  windowAssociation ]
# Index: []
#    Timestamp   NP   AssociatedClass   TimestampAssociation  \
# ...

# %% [markdown]
# # Mediamill Modified

# %%
df_batch = os.path.join(result_path, "mediamill_modified/CLR/CLR-MeasuresOverTime.csv")
df_upper = os.path.join(result_path, "mediamill_modified/EaISOUPTree/EaISOUPTree-MeasuresOverTime.csv")
df_bracis = os.path.join(result_path, "mediamill_modified/bracis_mediamill_modified/MeasuresOverTime.csv")
df_minasbr = os.path.join(result_path,"mediamill_modified/minas-br_mediamill_modified/MeasuresOverTime.csv")

df_final = plots.concat_datasets_for_ploting(df_batch,
                                            df_upper,
                                            df_bracis,
                                            df_minasbr)

print(df_final.Classifier.value_counts())

np_info_v1, concept_evolution_info  = plots.get_concept_evolution_np_info(os.path.join(result_path,"mediamill_modified/bracis_mediamill_modified/"))

np_info, concept_evolution_info  = plots.get_concept_evolution_np_info(os.path.join(result_path,"mediamill_modified/minas-br_mediamill_modified/"))

print(concept_evolution_info)
print(np_info)
print(np_info_v1)

plots.plot_measures_over_time_sinais(data=df_final,
                        np_info=np_info,
                        np_info_v1=np_info_v1,
                        concept_evolution_info=concept_evolution_info,
                        linewidth = 5,
                        markersize= 5,
                        savefig=True,
                        name_fig="mediamill_modified.pdf")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"
# MINAS-BR_v2    50
# EaISOUPTree    50
# UnkRM_v2       50
# CLR            50
# MINAS-BR_v1    50
# UnkRM_v1       50
# Name: Classifier, dtype: int64
# Empty DataFrame
# ...

# %% [markdown]
# # Mediamill Original

# %%
df_batch = os.path.join(result_path, "mediamill_original/CLR/CLR-Results.csv")
df_upper = os.path.join(result_path, "mediamill_original/EaBR/EaBR-Results.csv")
df_bracis = os.path.join(result_path, "mediamill_original/bracis_mediamill_original/MeasuresOverTime.csv")
df_minasbr = os.path.join(result_path,"mediamill_original/minas-br_mediamill_original/MeasuresOverTime.csv")

df_final = plots.concat_datasets_for_ploting(df_batch,
                                            df_upper,
                                            df_bracis,
                                            df_minasbr)


np_info_v1, concept_evolution_info  = plots.get_concept_evolution_np_info(os.path.join(result_path,"mediamill_original/bracis_mediamill_original/"))
np_info, concept_evolution_info  = plots.get_concept_evolution_np_info(os.path.join(result_path,"mediamill_original/minas-br_mediamill_original/"))

print(concept_evolution_info)
plots.plot_measures_over_time_sinais(data=df_final,
                        np_info=np_info,
                        np_info_v1=np_info_v1,
                        concept_evolution_info=concept_evolution_info,
                        linewidth = 5,
                        markersize= 5,
                        savefig=True,
                        name_fig="mediamill_original.pdf")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"
# Empty DataFrame
# Columns: [Timestamp,  NP,  AssociatedClass,  TimestampAssociation,  windowAssociation ]
# Index: []
# Empty DataFrame
# ...

# %% [markdown]
# # Nus-wide Modified

# %%
df_batch = os.path.join(result_path, "nus-wide_modified/BPMLL/BPMLL-MeasuresOverTime.csv")
df_upper = os.path.join(result_path, "nus-wide_modified/EaCC/EaCC-Results.csv")
df_bracis = os.path.join(result_path, "nus-wide_modified/bracis_nus-wide_modified/MeasuresOverTime.csv")
df_minasbr = os.path.join(result_path,"nus-wide_modified/minas-br_nus-wide_modified/MeasuresOverTime.csv")

df_final = plots.concat_datasets_for_ploting(df_batch,
                                            df_upper,
                                            df_bracis,
                                            df_minasbr)

np_info_v1, concept_evolution_info  = plots.get_concept_evolution_np_info(os.path.join(result_path,"nus-wide_modified/bracis_nus-wide_modified/"))
np_info, plots.concept_evolution_info  = plots.get_concept_evolution_np_info(os.path.join(result_path,"nus-wide_modified/minas-br_nus-wide_modified/"))


print(concept_evolution_info)
print(np_info)
print(np_info_v1)

plots.plot_measures_over_time_sinais(data=df_final,
                        np_info=np_info,
                        np_info_v1=np_info_v1,
                        concept_evolution_info=concept_evolution_info,
                        linewidth = 5,
                        markersize= 5,
                        savefig=True,
                        name_fig="nus-wide_modified.pdf")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"
# Empty DataFrame
# Columns: [Timestamp,  NP,  AssociatedClass,  TimestampAssociation,  windowAssociation ]
# Index: []
# Empty DataFrame
# ...

# %% [markdown]
# # Boxplots of Avg Results

# %%
datasets = {}

moa1_batch_homer = os.path.join(result_path, "MOA1/HOMER/HOMER-MeasuresOverTime.csv")
moa1_upper_eabr = os.path.join(result_path, "MOA1/EaBR/EaBR-MeasuresOverTime.csv")
moa1_bracis = os.path.join(result_path, "MOA1/bracis_moa1_final/MeasuresOverTime.csv")
moa1_minasbr = os.path.join(result_path,"MOA1/minas-br_MOA1/MeasuresOverTime.csv")

df_moa1_final = plots.concat_datasets_for_ploting(moa1_batch_homer,
                                            moa1_upper_eabr,
                                            moa1_bracis,
                                            moa1_minasbr)

datasets["MOA1"] = df_moa1_final.query("Classifier != 'UnkRM_v1' & Classifier != 'UnkRM_v2'")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"

# %%
moa2_batch = os.path.join(result_path, "MOA2/PSt/PSt-MeasuresOverTime.csv")
moa2_upper = os.path.join(result_path, "MOA2/EaBR/EaBR-MeasuresOverTime.csv")
moa2_bracis = os.path.join(result_path, "MOA2/bracis_moa2_final/MeasuresOverTime.csv")
moa2_minasbr = os.path.join(result_path,"MOA2/minas-br_MOA2/MeasuresOverTime.csv")

df_moa2_final = plots.concat_datasets_for_ploting(moa2_batch,
                                            moa2_upper,
                                            moa2_bracis,
                                            moa2_minasbr)
datasets["MOA2"] = df_moa2_final.query("Classifier != 'UnkRM_v1' & Classifier != 'UnkRM_v2'")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"

# %%
yeast_original_batch = os.path.join(result_path, "yeast_original/RandomSubspaceML/RandomSubspaceML-Results.csv")
yeast_original_upper = os.path.join(result_path, "yeast_original/EaCC/EaCC-Results.csv")
yeast_original_bracis = os.path.join(result_path, "yeast_original/bracis_yeast_original/MeasuresOverTime.csv")
yeast_original_minasbr = os.path.join(result_path,"yeast_original/minas-br_yeast_original/MeasuresOverTime.csv")

df_yeast_final = plots.concat_datasets_for_ploting(yeast_original_batch,
                                            yeast_original_upper,
                                            yeast_original_bracis,
                                            yeast_original_minasbr)

datasets["Yeast"] = df_yeast_final.query("Classifier != 'UnkRM_v1' & Classifier != 'UnkRM_v2'")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"

# %%
df_batch = os.path.join(result_path, "yeast_modified/CLR/CLR-MeasuresOverTime.csv")
df_upper = os.path.join(result_path, "yeast_modified/EaBR/EaBR-MeasuresOverTime.csv")
df_bracis = os.path.join(result_path, "yeast_modified/bracis_yeast_modified/MeasuresOverTime.csv")
df_minasbr = os.path.join(result_path,"yeast_modified/minas-br_yeast_modified/MeasuresOverTime.csv")

df_final = plots.concat_datasets_for_ploting(df_batch,
                                            df_upper,
                                            df_bracis,
                                            df_minasbr)

datasets["Yeast_modified"] = df_final.query("Classifier != 'UnkRM_v1' & Classifier != 'UnkRM_v2'")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"

# %%
df_batch = os.path.join(result_path, "scene_original/BPMLL/BPMLL-Results.csv")
df_upper = os.path.join(result_path, "scene_original/EaISOUPTree/EaISOUPTree-Results.csv")
df_bracis = os.path.join(result_path, "scene_original/bracis_scene_original/MeasuresOverTime.csv")
df_minasbr = os.path.join(result_path,"scene_original/minas-br_scene_original/MeasuresOverTime.csv")

df_final = plots.concat_datasets_for_ploting(df_batch,
                                            df_upper,
                                            df_bracis,
                                            df_minasbr)

datasets["Scene"] = df_final.query("Classifier != 'UnkRM_v1' & Classifier != 'UnkRM_v2'")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"

# %%
df_batch = os.path.join(result_path, "scene_modified/BPMLL/BPMLL-Results.csv")
df_upper = os.path.join(result_path, "scene_modified/EaISOUPTree/EaISOUPTree-MeasuresOverTime.csv")
df_bracis = os.path.join(result_path, "scene_modified/bracis_scene_modified/MeasuresOverTime.csv")
df_minasbr = os.path.join(result_path,"scene_modified/minas-br_scene_modified/MeasuresOverTime.csv")

df_final = plots.concat_datasets_for_ploting(df_batch,
                                            df_upper,
                                            df_bracis,
                                            df_minasbr)

datasets["Scene_modified"] = df_final.query("Classifier != 'UnkRM_v1' & Classifier != 'UnkRM_v2'")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"

# %%
df_batch = os.path.join(result_path, "mediamill_original/CLR/CLR-Results.csv")
df_upper = os.path.join(result_path, "mediamill_original/EaBR/EaBR-Results.csv")
df_bracis = os.path.join(result_path, "mediamill_original/bracis_mediamill_original/MeasuresOverTime.csv")
df_minasbr = os.path.join(result_path,"mediamill_original/minas-br_mediamill_original/MeasuresOverTime.csv")

df_final = plots.concat_datasets_for_ploting(df_batch,
                                            df_upper,
                                            df_bracis,
                                            df_minasbr)

datasets["Mediamill"] = df_final.query("Classifier != 'UnkRM_v1' & Classifier != 'UnkRM_v2'")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"

# %%
df_batch = os.path.join(result_path, "mediamill_modified/CLR/CLR-MeasuresOverTime.csv")
df_upper = os.path.join(result_path, "mediamill_modified/EaISOUPTree/EaISOUPTree-MeasuresOverTime.csv")
df_bracis = os.path.join(result_path, "mediamill_modified/bracis_mediamill_modified/MeasuresOverTime.csv")
df_minasbr = os.path.join(result_path,"mediamill_modified/minas-br_mediamill_modified/MeasuresOverTime.csv")

df_final = plots.concat_datasets_for_ploting(df_batch,
                                            df_upper,
                                            df_bracis,
                                            df_minasbr)

datasets["Mediamill_modified"] = df_final.query("Classifier != 'UnkRM_v1' & Classifier != 'UnkRM_v2'")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"

# %%
df_batch = os.path.join(result_path, "nus-wide_modified/BPMLL/BPMLL-MeasuresOverTime.csv")
df_upper = os.path.join(result_path, "nus-wide_modified/EaCC/EaCC-Results.csv")
df_bracis = os.path.join(result_path, "nus-wide_modified/bracis_nus-wide_modified/MeasuresOverTime.csv")
df_minasbr = os.path.join(result_path,"nus-wide_modified/minas-br_nus-wide_modified/MeasuresOverTime.csv")

df_final = plots.concat_datasets_for_ploting(df_batch,
                                            df_upper,
                                            df_bracis,
                                            df_minasbr)


datasets["NUS-WIDE_modified"] = df_final.query("Classifier != 'UnkRM_v1' & Classifier != 'UnkRM_v2'")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"

# %%
sns.set_theme(context='notebook', style="whitegrid")
plots.boxplot_avg_results(datasets, "F1M", savefig=True, name_fig="boxplots_avg_f1m.pdf")

# %% [markdown]
# ## Precision Recall

# %%
datasets = {}

yeast_original_batch = os.path.join(result_path, "yeast_original/RandomSubspaceML/RandomSubspaceML-Results.csv")
yeast_original_upper = os.path.join(result_path, "yeast_original/EaCC/EaCC-Results.csv")
yeast_original_bracis = os.path.join(result_path, "yeast_original/bracis_yeast_original/MeasuresOverTime.csv")
yeast_original_minasbr = os.path.join(result_path,"yeast_original/minas-br_yeast_original/MeasuresOverTime.csv")

df_yeast_final = plots.concat_datasets_for_ploting(yeast_original_batch,
                                            yeast_original_upper,
                                            yeast_original_bracis,
                                            yeast_original_minasbr)

datasets["Yeast"] = df_yeast_final.query("Classifier != 'UnkRM_v1' & Classifier != 'UnkRM_v2'")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"

# %%
df_batch = os.path.join(result_path, "yeast_modified/CLR/CLR-MeasuresOverTime.csv")
df_upper = os.path.join(result_path, "yeast_modified/EaBR/EaBR-MeasuresOverTime.csv")
df_bracis = os.path.join(result_path, "yeast_modified/bracis_yeast_modified/MeasuresOverTime.csv")
df_minasbr = os.path.join(result_path,"yeast_modified/minas-br_yeast_modified/MeasuresOverTime.csv")

df_final = plots.concat_datasets_for_ploting(df_batch,
                                            df_upper,
                                            df_bracis,
                                            df_minasbr)

datasets["Yeast_modified"] = df_final.query("Classifier != 'UnkRM_v1' & Classifier != 'UnkRM_v2'")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"

# %%
df_batch = os.path.join(result_path, "mediamill_original/CLR/CLR-Results.csv")
df_upper = os.path.join(result_path, "mediamill_original/EaBR/EaBR-Results.csv")
df_bracis = os.path.join(result_path, "mediamill_original/bracis_mediamill_original/MeasuresOverTime.csv")
df_minasbr = os.path.join(result_path,"mediamill_original/minas-br_mediamill_original/MeasuresOverTime.csv")

df_final = plots.concat_datasets_for_ploting(df_batch,
                                            df_upper,
                                            df_bracis,
                                            df_minasbr)

datasets["Mediamill"] = df_final.query("Classifier != 'UnkRM_v1' & Classifier != 'UnkRM_v2'")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"

# %%
df_batch = os.path.join(result_path, "mediamill_modified/CLR/CLR-MeasuresOverTime.csv")
df_upper = os.path.join(result_path, "mediamill_modified/EaISOUPTree/EaISOUPTree-MeasuresOverTime.csv")
df_bracis = os.path.join(result_path, "mediamill_modified/bracis_mediamill_modified/MeasuresOverTime.csv")
df_minasbr = os.path.join(result_path,"mediamill_modified/minas-br_mediamill_modified/MeasuresOverTime.csv")

df_final = plots.concat_datasets_for_ploting(df_batch,
                                            df_upper,
                                            df_bracis,
                                            df_minasbr)

datasets["Mediamill_modified"] = df_final.query("Classifier != 'UnkRM_v1' & Classifier != 'UnkRM_v2'")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_classifier["Classifier"] = "MINAS-BR_v2"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minasbr_unkrm["Classifier"] = "UnkRM_v2"

# %%
datasets["Mediamill_modified"]
# Out:
#      Classifier  Timestamp        F1        SA        HL        Pr        Re  \
# 0   MINAS-BR_v2          1  0.305549  0.000000  0.000000  0.209155  0.637627
# 1   MINAS-BR_v2          2  0.301850  0.000000  0.001334  0.205516  0.629024
# 2   MINAS-BR_v2          3  0.301688  0.000000  0.001779  0.204335  0.634770
# 3   MINAS-BR_v2          4  0.308829  0.000000  0.001334  0.208064  0.660261
# 4   MINAS-BR_v2          5  0.322873  0.000000  0.001068  0.218623  0.694842
# ..          ...        ...       ...       ...       ...       ...       ...
# 45          CLR         46  0.554743  0.030162  0.000000  0.592757  0.581663
# 46          CLR         47  0.555369  0.030568  0.000000  0.592965  0.583418
# 47          CLR         48  0.555874  0.030653  0.000000  0.593027  0.585213
# 48          CLR         49  0.557489  0.031060  0.000000  0.594118  0.587777
# 49          CLR         50  0.558585  0.031651  0.000000  0.594684  0.589888
#
# ...

# %%
sns.set_theme(context='notebook', style="whitegrid")
plots.boxplot_avg_results(datasets, "PrM", savefig=True, name_fig="boxplots_avg_PrM.pdf")

# %%
sns.set_theme(context='notebook', style="whitegrid")
plots.boxplot_avg_results(datasets, "ReM", savefig=True, name_fig="boxplots_avg_PrM.pdf")

# %%
sns.barplot(data=datasets["Mediamill_modified"], x="Classifier", y="PrM")
# Out:
# <AxesSubplot:xlabel='Classifier', ylabel='PrM'>

# %%
sns.barplot(data=datasets["Mediamill_modified"], x="Classifier", y="ReM")
# Out:
# <AxesSubplot:xlabel='Classifier', ylabel='ReM'>

# %%
plots.barplot_precision_recall(datasets, savefig=True, name_fig="barplot_precision_recall.pdf")
# Out:
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:195: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pr["metric"] = "PrM"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   re["metric"] = "ReM"
# /home/joel/MINAS-BR_ASOC/data_analysis/scripts/plots.py:195: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Parameters sensitivity plots

# %%
results_path = "/home/joel/resultsAsoc2021/parameters_sensitivity_completo/"

# %%
moa2 = os.path.join(results_path, "MOA2/fullResults.csv")

moa1_results = pd.read_csv(os.path.join(results_path, "MOA1/fullResults.csv"))
moa2_results = pd.read_csv(os.path.join(results_path, "MOA2/fullResults.csv"))
nuswide_modified_results = pd.read_csv(os.path.join(results_path, "nus-wide_modified/fullResults.csv"))
scene_original_results = pd.read_csv(os.path.join(results_path, 'scene_original/fullResults.csv'))
yeast_original_results = pd.read_csv(os.path.join(results_path, 'yeast_original/fullResults.csv'))

# %%
moa1_results["dataset"] = "MOA1"
moa2_results["dataset"] = "MOA2"
nuswide_modified_results["dataset"] = "NUS-WIDE_modified"
scene_original_results['dataset'] = 'scene'
yeast_original_results['dataset'] = 'yeast'
todos_datasets = pd.concat([moa1_results, 
                            moa2_results, 
                            nuswide_modified_results, 
                            scene_original_results,
                            yeast_original_results])

ax = sns.boxplot(data=todos_datasets, x="dataset", y="F1M")
ax.set_ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
moa1_results.shortTermMemoryLimit.unique()
# Out:
# array([0.1 , 0.25, 0.5 , 0.75, 1.  ])

# %%
moa1_results[moa1_results.windowsSize == 200]

dict = {200: {
    0.01: {
        0.1: ,
        0.25: moa1_results[moa1_results.shortTermMemoryLimit == 0.25].F1M,
        0.5: moa1_results[moa1_results.shortTermMemoryLimit == 0.5].F1M,
        0.75: moa1_results[moa1_results.shortTermMemoryLimit == 0.75].F1M,
        1: moa1_results[moa1_results.shortTermMemoryLimit == 1].F1M       
    }
}}
print(dict)
# Out:
#   File "<ipython-input-49-e3cbfb7023b1>", line 5
#     0.1: ,
#          ^
# SyntaxError: invalid syntax

# %%
moa1_results.windowsSize.unique()
# Out:
# array([ 200,  500, 1000, 2000])

# %%
plt.figure()
sns.set_theme(context='notebook', style='ticks', font_scale=1.7)
ax = sns.relplot(
    data=moa1_results, x=moa1_results.windowsSize.astype('str'), y="F1M",
    hue=moa1_results.k_ini.astype('str'),
    col="shortTermMemoryLimit",
    markers=True, style=moa1_results.k_ini.astype('str'),
    kind="line",
    col_wrap=3,
    markersize=10,
    legend='full'
)

ax.set(ylim=(0, 1))
# ax.axes[0][0].set_title('\u03F4 = \u03C9/10')
ax.set_xlabels('\u03C9 - window size')
cont = 0
values = ['10', '4', '2', '1.33']
for i in ax.axes:
    i.hlines(y=0.75, xmin="200", xmax="2000", color='black',
             linestyle='dashed', label='baseline')
    try:
        i.set_title('\u03F4 = \u03C9/'+values[cont])
    except IndexError:
        i.set_title('\u03F4 = \u03C9')
    cont+=1


plt.savefig('moa1_parameters_sensitivity.pdf',
            dpi=300, format='pdf', bbox_inches='tight')
plt.show()

# %%
plt.figure()
sns.set_theme(context='notebook', style='ticks', font_scale=1.7)

ax = sns.relplot(
    data=moa1_results,
    x=moa1_results.windowsSize.astype('str'), y="NP",
    hue=moa1_results.k_ini.astype('str'),
    col="shortTermMemoryLimit",
    markers=True, 
    style=moa1_results.k_ini.astype('str'),
    kind="line",
    col_wrap=3,
    markersize=10,
    legend='full'
)

ax.set_xlabels('\u03C9 - window size')
ax.set_ylabels("Number of NPs")
cont = 0
values = ['10', '4', '2', '1.33']
for i in ax.axes:
    try:
        i.set_title('\u03F4 = \u03C9/'+values[cont])
    except IndexError:
        i.set_title('\u03F4 = \u03C9')
    cont+=1


plt.savefig('moa1_parameters_sensitivity_nps.pdf',
            dpi=300, format='pdf', bbox_inches='tight')
plt.show()

# %%
plt.figure()
sns.set_theme(context='notebook', style='ticks',font_scale=1.4)
ax = sns.relplot(
    data=moa2_results, 
    x="windowsSize",
    y="F1M",
    hue=moa2_results.k_ini.astype('str'),
    col="shortTermMemoryLimit",
    markers=True,
    style=moa2_results.k_ini.astype('str'),
    kind="line",
    col_wrap=3,
    markersize=10
)

ax.set(ylim=(0.4,0.6))

plt.savefig('moa2_parameters_sensitivity.pdf', dpi=300, format='pdf', bbox_inches='tight')
plt.show()

# %%
sns.catplot(x="shortTermMemoryLimit", y="F1M", kind="boxen",
            data=moa1_results)

# %%
plt.figure()
ax = sns.boxplot(data=nuswide_modified_results, x='shortTermMemoryLimit', y='F1M', hue='k_ini')
ax.set_ylim([0.275,0.325])
plt.show()
plt.figure()
sns.boxplot(data=nuswide_modified_results, x='shortTermMemoryLimit', y='F1M', hue='windowsSize')
plt.show()
plt.figure()
sns.boxplot(data=nuswide_modified_results, x='windowsSize', y='F1M', hue='k_ini')
plt.show()

# %%
sns.boxplot(data=nuswide_modified_results, hue='windowsSize', y='F1M', x='k')

# %%
sns.boxplot(data=moa2_results, hue='windowsSize', y='F1M', x='shortTermMemoryLimit')
# Out:
# <AxesSubplot:xlabel='shortTermMemoryLimit', ylabel='F1M'>

# %%
sns.boxplot(data=moa1_results, hue='windowsSize', y='F1M', x='shortTermMemoryLimit')
# Out:
# <AxesSubplot:xlabel='shortTermMemoryLimit', ylabel='F1M'>

# %%
ax = sns.ecdfplot(resultados_completos.F1M)
sns.ecdfplot(resultados_completos.precision, ax=ax)
sns.ecdfplot(resultados_completos.recall, ax=ax)
ax.set_xlim([0,1])
# Out:
# (0.0, 1.0)

# %%
sns.boxplot(y=resultados_completos.F1M, x = resultados_completos.k_ini)
# Out:
# <AxesSubplot:xlabel='k_ini', ylabel='F1M'>

# %%
ax = sns.boxplot(y=resultados_completos.F1M, x = resultados_completos.windowsSize)

# %%
ax = sns.boxplot(y=resultados_completos.F1M, x = resultados_completos.shortTermMemoryLimit,
                hue=resultados_completos.windowsSize)

# %%
ax = sns.boxplot(y=resultados_completos.precision, x = resultados_completos.shortTermMemoryLimit,
                hue=resultados_completos.windowsSize)

# %%
ax = sns.boxplot(y=resultados_completos.recall, x = resultados_completos.shortTermMemoryLimit,
                hue=resultados_completos.windowsSize)

# %%
ax = sns.boxplot(y=resultados_completos.subsetAccuracy, x = resultados_completos.shortTermMemoryLimit,
                hue=resultados_completos.windowsSize)
